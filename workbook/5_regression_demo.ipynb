# %% [markdown]
# # Regression and correlation analyses
#
# Regression and correlation analyses are statistical techniques used to examine the relationships between variables, allowing engineers to understand how changes in one variable may affect another.
# By quantifying these relationships, engineers can make predictions and informed decisions based on data, which is essential for optimizing designs and processes in various engineering fields.

# %% [markdown]
# ## Summary of commands
#
# In this exercise, we will demonstrate the following:
#
# - [**SciPy**](https://docs.scipy.org/doc//scipy/index.html), specifically the [**statistics**](https://docs.scipy.org/doc//scipy/tutorial/stats.html) package.
#   - [`scipy.stats.ttest_1samp`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_1samp.html) - $t$-test for the mean of one sample.
#   - [`scipy.stats.ttest_ind`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html) - $t$-test for the means of two _independent_ samples.
#   - [`scipy.stats.ttest_rel`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_rel.html) - $t$-test for the means of two _related_ samples.
# - We will also work with $z$-tests for the difference between means of normally distributed data.
#   Shockingly, while this function exists in MATLAB ([`ztest()`](https://www.mathworks.com/help/stats/ztest.html)), it does not exist in common Python libraries ([`statsmodels`](https://www.statsmodels.org/dev/generated/statsmodels.stats.weightstats.ztest.html) isn't quite accurate), so we'll simply write our own! 😎
#   - In writing this function, we will use the `sf()` **survival function** which is $1 - \text{CDF}$.

# %%
# Define a
a = 2
print(a)
a;
# Out:
# 2

# %%
# Define b
b = 5
b
# Out:
# 5

# %%
# Compute c
c = a + b ** 2   # exponentiation is two asterisks (not carat!)
print(c)
# Out:
# 27

# %%
# Compute a different value for c
c = a + 2 * b
print(c)
# Out:
# 12

# %% [markdown]
# ## "Restart and run all" or it didn't happen
#
# With Jupyter notebooks, you have the power to run cells in any order you want.
# And with great power comes great responsibility.
# It's easy to get variables mixed up and then your notebook starts giving you errors;
# or worse someone might intentionally use this to conceal duplicitly (e.g., their notebook appears functional based on cell outputs, but actually isn't when executed from top to bottom).
#
# So if you ever need to reset anything, the easiest way is to go to `Runtime > Restart session and run all` on Colab or `Run > Restart Kernel and Run All Cells...` on Jupyter Lab.
# This clears all variables and outputs from the workspace and runs your notebook from top to bottom.
#
# ```{note}
# If you're coming from MATLAB, you may be familiar with putting `clear; close all; clc;` at the top of your script.
# This is essentially equivalent.
# ```
#
# Without rerunning all the cells, you can always just restart the kernel (equivalent to `clear` in MATLAB).
# Try that now by clicking `Runtime > Restart session` or `Kernel > Restart Kernel...` and then try running the next cell, which shows the variable you computed before clearing the runtime.

# %%
c
# Out:
# -----------------------------------------------
# NameError     Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined
